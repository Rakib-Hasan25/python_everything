# %% [markdown]
# <a href="https://colab.research.google.com/github/Rakib-Hasan25/python_everything/blob/main/Seaborn_fundamental.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Why Seaborn
# + provides a layer over mathplotlib for simpler to use , reduce line of code,
# + better aesthetics ( graph looking good than mathplotlib)
# + more graphs included
# + it is famous ,used in industry
#
# ###+ confusion:
# two function name different , but doing same type of thing or ploting
# same kind of graph
#
# ###Types of function
# + Figure level
# + Axis level
#
# Seaborn Roadmap
# + Relational Plot
# + Distribution Plot
# + Categorical Plot
# + Regression Plot
# + Matrix Plot
# + Multiplots

# %% [markdown]
# 1. Relational Plot
#
# + to see the statistical relation between 2 or more variables.
# + Bivariate Analysis
#
#
# Plots under this section
#
# + scatterplot
# + lineplot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px # using for an inbuild dataset

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# scatter plot -> axes level function  -> graph look like rectengular shape
sns.scatterplot(data = tips , x='total_bill' , y = 'tip' )
# in mathplot lib we have to write code for leveling but here not need
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
#now we want differentiate between male and female
sns.scatterplot(data=tips, x='total_bill', y='tip',hue='sex')


# here we can we a legend box appear in the graph but we have to write code for that in mathplotlib
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# we can also do
sns.scatterplot(data=tips, x='total_bill', y='tip',hue='sex',style='time',size='size')
# size increase dot size  # hue change color of dot # style change design of dot
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# relplot -> figure level ->  graph look like square shape



# it is always better to use figure level
# because using it we can create many more axes level graph



# legend box(sex,time,etc repesentaion box ) is outside from the graph which doesn't distrub in graph
# but in scatter plot box can over lap with graph


sns.relplot(data=tips, x='total_bill', y='tip', kind='scatter',hue='sex',style='time',size='size')
# we give kind = "scatter" for scatter graph

# %% [markdown]
# #line plot
#
# # to show continutity
# # when there are time in x axis ( time series data )

# %%
# line .plot

gap = px.data.gapminder() # it is inbuild dataset from plotly
gap
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
#i want to see the lifeExp of bangladesh how improve or worst year by year
gap = px.data.gapminder()

temp_df = gap[gap['country']=='Bangladesh']
# Out:
#         country continent  year  lifeExp        pop    gdpPercap iso_alpha  \
# 96   Bangladesh      Asia  1952   37.484   46886859   684.244172       BGD
# 97   Bangladesh      Asia  1957   39.348   51365468   661.637458       BGD
# 98   Bangladesh      Asia  1962   41.216   56839289   686.341554       BGD
# 99   Bangladesh      Asia  1967   43.453   62821884   721.186086       BGD
# 100  Bangladesh      Asia  1972   45.252   70759295   630.233627       BGD
# 101  Bangladesh      Asia  1977   46.923   80428306   659.877232       BGD
# 102  Bangladesh      Asia  1982   50.009   93074406   676.981866       BGD
# 103  Bangladesh      Asia  1987   52.819  103764241   751.979403       BGD
# 104  Bangladesh      Asia  1992   56.018  113704579   837.810164       BGD
# 105  Bangladesh      Asia  1997   59.412  123315288   972.770035       BGD
# 106  Bangladesh      Asia  2002   62.013  135656790  1136.390430       BGD
# ...

# %%
#axes level function
gap = px.data.gapminder()

temp_df = gap[gap['country']=='Bangladesh']
sns.lineplot(data=temp_df, x='year', y='lifeExp')
# Out:
# <Axes: xlabel='year', ylabel='lifeExp'>

# %%
#using figure level

sns.relplot(data = temp_df, x = 'year', y='lifeExp', kind='line')

#shape of the figure in squre type

# %%
# three country data

temp_df= gap[gap['country'].isin(['India',"Bangladesh",'China'])]
temp_df.head(30)
# Out:
#         country continent  year   lifeExp         pop    gdpPercap iso_alpha  \
# 96   Bangladesh      Asia  1952  37.48400    46886859   684.244172       BGD
# 97   Bangladesh      Asia  1957  39.34800    51365468   661.637458       BGD
# 98   Bangladesh      Asia  1962  41.21600    56839289   686.341554       BGD
# 99   Bangladesh      Asia  1967  43.45300    62821884   721.186086       BGD
# 100  Bangladesh      Asia  1972  45.25200    70759295   630.233627       BGD
# 101  Bangladesh      Asia  1977  46.92300    80428306   659.877232       BGD
# 102  Bangladesh      Asia  1982  50.00900    93074406   676.981866       BGD
# 103  Bangladesh      Asia  1987  52.81900   103764241   751.979403       BGD
# 104  Bangladesh      Asia  1992  56.01800   113704579   837.810164       BGD
# 105  Bangladesh      Asia  1997  59.41200   123315288   972.770035       BGD
# 106  Bangladesh      Asia  2002  62.01300   135656790  1136.390430       BGD
# ...

# %%
#figure_level
sns.relplot(kind='line', data = temp_df, x= 'year', y= 'lifeExp', hue = 'country')

# %%
# axes level

sns.lineplot(data = temp_df, x= 'year', y= 'lifeExp', hue = 'country')

# difference is in legend box
# Out:
# <Axes: xlabel='year', ylabel='lifeExp'>

# %%
# giving a country from different continent

temp_df= gap[gap['country'].isin(['India',"Brazil",'China'])]
temp_df.head(30)


#figure_level
sns.relplot(kind='line', data = temp_df, x= 'year', y= 'lifeExp', hue = 'country', style='continent') # style is given for continent

# %%
#facet plot

# it will work for figure level function not work for lineplot or scatterplot



# using this for any perticular catgorical data i can plot multiple graph
tips


#column basis
sns.relplot(data=tips, x='total_bill', y='tip', kind='scatter',col='sex') # col is using for facet plot

# %%
#row basis
sns.relplot(data=tips, x='total_bill', y='tip', kind='scatter',row='sex')

# %%
# column and row basis
sns.relplot(data=tips, x='total_bill', y='tip', kind='scatter',row='sex',col='smoker')

# %%
#wrap
# if we want to limit in row or column how many graph will be shown

gap
sns.relplot(data=gap, x='lifeExp', y='gdpPercap', kind='scatter',col='year')


# but this is not readable

# %%
#wrap function
sns.relplot(data=gap, x='lifeExp', y='gdpPercap', kind='scatter',col='year',col_wrap=3)

# %% [markdown]
# #2.Distribution Plots
# + used for univariate analysis
# + used to find out the distribution
# + Range of the observation
# + Central Tendency
# + is the data bimodal?
# + Are there outliers?
#
# #### plots under distribution plot
#
# + histplot(histogram)
# + kdeplot
# + rugplot

# %%
#figure level -> displot
#axes level -> hisplot,kdeplot,rugplot

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# plotting univariate histogram

#using axes level

sns.histplot(data=tips, x='total_bill')
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
#using figure level
sns.displot(data=tips, x = 'total_bill', kind='hist')

# %%
#bins perameter
sns.displot(data=tips, x = 'total_bill', kind='hist', bins=20) # number of bins

# %%
# It’s also possible to visualize the distribution of a categorical variable using the logic of a histogram.
# Discrete bins are automatically set for categorical variables

#i want to know customer came in every day
#typically we can say it  countplot ( categorical data's count)
sns.displot(data=tips, x='day', kind='hist')

# %%
# hue parameter
sns.displot(data=tips, x='tip', kind='hist',hue='sex')


# histogram for male or female customer the amount of tip they give

# %%
# to see more clearly

# element -> step
sns.displot(data=tips, x='tip', kind='hist',hue='sex',element='step')

# %%
# now doing a very interestiong thing
# most important data set
titanic = sns.load_dataset('titanic') # default dataset in seaborn
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# histogram for different age group
sns.displot(data=titanic, x = 'age', kind='hist')

# %%
# male and female distribution in age group
sns.displot(data=titanic, x = 'age', kind='hist', element ='step', hue = 'sex')

# %%
# survived people distributaion in age group
sns.displot(data=titanic, x = 'age', kind='hist', element ='step', hue = 'survived')

# %%
# faceting using col and row -> not work on histplot function


# tip giving distribution for different gender
sns.displot(data=tips, x='tip', kind='hist',col='sex',element='step')

# %% [markdown]
# # KDEplot
#
# ###+kernal density estimation
#
# ##### kdeplot
# #### Rather than using discrete bins, a KDE plot smooths the observations with a Gaussian kernel(function), producing a continuous density estimate---> cover in statistics

# %%
sns.kdeplot(data=tips,x='total_bill')

# amount of bills distribution

# it giving probability of entire data set of having bill in a range
# in their , 20 bills having the greater probability
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.displot(data=tips,x='total_bill',kind='kde')

# %%
#hue
sns.displot(data=tips,x='total_bill',kind='kde',hue='sex')

# %%
sns.displot(data=tips,x='total_bill',kind='kde',hue='sex',fill=True,height=5,aspect=2)

# %% [markdown]
# #RugPlot
#
# #### it is used for suppoting the marginal distribution
# ####not so much used alone
# ##### Plot marginal distributions by drawing ticks along the x and y axes.
#
# ##### This function is intended to complement other plots by showing the location of individual observations in an unobtrusive way.

# %%
sns.kdeplot(data=tips,x='total_bill')
sns.rugplot(data=tips,x='total_bill') # set of tik on x axis which represent the density(distribution)
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
# Bivariate histogram
# A bivariate histogram bins the data within rectangles that tile the plot
# and then shows the count of observations within each rectangle with the fill color

# sns.histplot(data=tips, x='total_bill', y='tip')
sns.displot(data=tips, x='total_bill', y='tip',kind='hist')

# here we want to have relation between total bils and tip ,
#where bill and tip intersect each other grid show more brighter , this represent
# relationship between total_bill and tip

# %%
# Bivariate Kdeplot
# a bivariate KDE plot smoothes the (x, y) observations with a 2D Gaussian
sns.kdeplot(data=tips, x='total_bill', y='tip')


# if lines are closer then there an greater density
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# #2.Matrix plot
#
#
# + HeatMap
# + ClusterMap

# %%
gap
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
gap.pivot(index='country', columns='year',values = 'lifeExp')
# Out:
# year                  1952    1957    1962    1967    1972    1977    1982  \
# country
# Afghanistan         28.801  30.332  31.997  34.020  36.088  38.438  39.854
# Albania             55.230  59.280  64.820  66.220  67.690  68.930  70.420
# Algeria             43.077  45.685  48.303  51.407  54.518  58.014  61.368
# Angola              30.015  31.999  34.000  35.985  37.928  39.483  39.942
# Argentina           62.485  64.399  65.142  65.634  67.065  68.481  69.942
# ...                    ...     ...     ...     ...     ...     ...     ...
# Vietnam             40.412  42.887  45.363  47.838  50.254  55.764  58.816
# West Bank and Gaza  43.160  45.671  48.127  51.631  56.532  60.765  64.406
# Yemen, Rep.         32.548  33.970  35.180  36.984  39.848  44.175  49.113
# Zambia              42.038  44.077  46.023  47.768  50.107  51.386  51.821
# Zimbabwe            48.451  50.469  52.358  53.995  55.635  57.674  60.363
#
# year                  1987    1992    1997    2002    2007
# ...

# %%
# Heatmap -> # axes level function

# Plot rectangular data as a color-encoded matrix
temp_df = gap.pivot(index='country',columns='year',values='lifeExp')


plt.figure(figsize=(15,15))
sns.heatmap(temp_df)
# Out:
# <Axes: xlabel='year', ylabel='country'>

# %%
#annot

eu_coun= gap[gap['continent']=='Europe'].pivot(index ='country',columns='year',values='lifeExp') #
# Out:
# year                      1952    1957    1962    1967    1972    1977  \
# country
# Albania                 55.230  59.280  64.820  66.220  67.690  68.930
# Austria                 66.800  67.480  69.540  70.140  70.630  72.170
# Belgium                 68.000  69.240  70.250  70.940  71.440  72.800
# Bosnia and Herzegovina  53.820  58.450  61.930  64.790  67.450  69.860
# Bulgaria                59.600  66.610  69.510  70.420  70.900  70.810
# Croatia                 61.210  64.770  67.130  68.500  69.610  70.640
# Czech Republic          66.870  69.030  69.900  70.380  70.290  70.710
# Denmark                 70.780  71.810  72.350  72.960  73.470  74.690
# Finland                 66.550  67.490  68.750  69.830  70.870  72.520
# France                  67.410  68.930  70.510  71.550  72.380  73.830
# Germany                 67.500  69.100  70.300  70.800  71.000  72.500
# Greece                  65.860  67.860  69.510  71.000  72.340  73.680
# ...

# %%
plt.figure(figsize=(15,15))
sns.heatmap(eu_coun, annot=True,linewidth=0.5)#annot give value number
# Out:
# <Axes: xlabel='year', ylabel='country'>

# %%
#cmap --> changing color theme

plt.figure(figsize=(15,15))
sns.heatmap(eu_coun, annot=True,cmap='summer')
# Out:
# <Axes: xlabel='year', ylabel='country'>

# %% [markdown]
# #cluster map
#
#
#
# #### Plot a matrix dataset as a hierarchically-clustered heatmap.
#
# #### This function requires scipy to be available.

# %%
irs= px.data.iris() # famous dataset from plotly

irs
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      species_id
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ..          ...
# ...

# %%
sns.clustermap(irs.iloc[:,[0,1,2,3]])
